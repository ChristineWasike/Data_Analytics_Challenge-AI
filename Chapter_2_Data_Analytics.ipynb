# %% [markdown]
# ## <center>Chapter 2: Data Analytics</center>
#
# ####  <center>Rwanda  Revenue Authority</center>
# ![RR%20Logo.png](attachment:RR%20Logo.png)
#
# #### <center>Methodology</center>

# %%
# Add in the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# loading the financial and sentimental data sets
# Us local government data set
data = pd.read_csv("Tax_Revenue_By_Month.csv")

# Sentiment data set on each major US airline
sentiment_data = pd.read_csv("Tweets.csv")

# %%
# Viewing the first 10 data entries
data.head(10)
# Out:
#        Month  Calendar Year Fiscal Year    Withholding  \
# 0       July           2011   FY 2011-12           NaN
# 1     August           2011   FY 2011-12  2.771524e+08
# 2  September           2011   FY 2011-12  3.980483e+08
# 3    October           2011   FY 2011-12  4.086132e+08
# 4   November           2011   FY 2011-12  4.657074e+08
# 5   December           2011   FY 2011-12  5.409526e+08
# 6    January           2012   FY 2011-12  4.931073e+08
# 7   February           2012   FY 2011-12  4.817713e+08
# 8      March           2012   FY 2011-12  5.648959e+08
# 9      April           2012   FY 2011-12  3.729647e+08
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
# 1                   2.320268e+07   2.666841e+08     927436.95      8942131.10
# 2                   2.748813e+08   2.896617e+08    2769766.79     10132507.23
# ...

# %%
data.shape
# Out:
# (114, 51)

# %%
# The last 10 columns in the financial dataset
data.tail(10)
# Out:
#          Month  Calendar Year Fiscal Year    Withholding  \
# 104      March           2020   FY 2019-20  7.289689e+08
# 105      April           2020   FY 2019-20  5.503504e+08
# 106        May           2020   FY 2019-20  4.937124e+08
# 107       June           2020   FY 2019-20  1.221656e+09
# 108       July           2020   FY 2020-21           NaN
# 109     August           2020   FY 2020-21  3.589270e+08
# 110  September           2020   FY 2020-21  5.076667e+08
# 111    October           2020   FY 2020-21  5.168324e+08
# 112   November           2020   FY 2020-21  5.411660e+08
# 113   December           2020   FY 2020-21  7.176408e+08
#
#      Income Tax Estimates & Finals  Sales and Use  Business Use  \
# 104                   6.376924e+07   4.103620e+08    1421833.50
# 105                   1.187917e+08   3.273893e+08    6833814.41
# 106                   5.351338e+07   2.317350e+08    5546922.93
# 107                   1.319174e+09   9.221990e+08    7992339.18
# ...

# %%
# Checking for duplicated data: There was no duplicated call
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 109    False
# 110    False
# 111    False
# 112    False
# 113    False
# Length: 114, dtype: bool

# %%
data.describe()
# Out:
#        Calendar Year   Withholding  Income Tax Estimates & Finals  \
# count     114.000000  1.040000e+02                   1.040000e+02
# mean     2015.736842  5.319856e+08                   2.958321e+08
# std         2.762110  1.808589e+08                   3.742321e+08
# min      2011.000000  2.553158e+08                   1.744387e+07
# 25%      2013.000000  4.234121e+08                   4.586376e+07
# 50%      2016.000000  4.922284e+08                   1.116656e+08
# 75%      2018.000000  5.678165e+08                   4.011141e+08
# max      2020.000000  1.221656e+09                   1.563131e+09
#
#        Sales and Use  Business Use  Room Occupancy  Electric Generation  \
# count   1.040000e+02  9.900000e+01    1.040000e+02         2.700000e+01
# mean    3.787298e+08  5.320849e+06    1.017719e+07         5.617446e+06
# std     1.443211e+08  3.214779e+06    4.538633e+06         7.312795e+06
# min     1.771052e+08  6.627903e+05    2.273054e+06         0.000000e+00
# ...

# %%
data.nunique()
# Out:
# Month                                             13
# Calendar Year                                     10
# Fiscal Year                                       10
# Withholding                                      104
# Income Tax Estimates & Finals                    104
# Sales and Use                                    104
# Business Use                                      99
# Room Occupancy                                   104
# Electric Generation                               19
# Business Entity                                  108
# Corporation Business                             104
# Pass-Through Entity                               26
# Unrelated Business Income                        114
# Cable, Satellite and Video                        91
# PEG Account                                       87
# Electric & Power                                  69
# Gas & Electric                                    86
# Railroads                                         37
# ...

# %%
# Returning the first row in the dataset given that the argument provided is 1
data.head(1)
# Out:
#   Month  Calendar Year Fiscal Year   Withholding  \
# 0  July           2011   FY 2011-12          NaN
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
#
#    Electric Generation  Business Entity  ...  Nursing Home User Fee  \
# 0                  NaN        381060.92  ...                    NaN
#
#    Hospitals  Intermediate Care Facility  Ambulatory Surgical Centers  \
# 0        NaN                         NaN                          NaN
#
#    Gasoline  Special Fuel  Motor Carrier   Licenses  \
# 0       NaN           NaN            NaN  168768.74
#
#    Beverage Container Deposits  Total Revenue
# 0                          NaN    30584297.58
#
# [1 rows x 51 columns]

# %%
# Transforming data: Changed a column title
data.rename(columns = {'Income Tax Estimates & Finals': 'Tax Approximate'})
# Out:
#          Month  Calendar Year Fiscal Year    Withholding  Tax Approximate  \
# 0         July           2011   FY 2011-12           NaN              NaN
# 1       August           2011   FY 2011-12  2.771524e+08     2.320268e+07
# 2    September           2011   FY 2011-12  3.980483e+08     2.748813e+08
# 3      October           2011   FY 2011-12  4.086132e+08     6.944227e+07
# 4     November           2011   FY 2011-12  4.657074e+08     8.803835e+07
# ..         ...            ...          ...           ...              ...
# 109     August           2020   FY 2020-21  3.589270e+08     3.323360e+07
# 110  September           2020   FY 2020-21  5.076667e+08     3.134048e+08
# 111    October           2020   FY 2020-21  5.168324e+08     1.064493e+08
# 112   November           2020   FY 2020-21  5.411660e+08     3.622986e+07
# 113   December           2020   FY 2020-21  7.176408e+08     8.244990e+07
#
#      Sales and Use  Business Use  Room Occupancy  Electric Generation  \
# ...

# %%
data.index[4]
# Out:
# 4

# %% [markdown]
# ### STAGE 3 DATA CLEANING, PREPARATION, DATA TRANSFORMATION AND INTERGRATION

# %%
# Remove in specific rows and columns with Null/NaN values
data.drop(data.index[0])
# Out:
#          Month  Calendar Year Fiscal Year    Withholding  \
# 1       August           2011   FY 2011-12  2.771524e+08
# 2    September           2011   FY 2011-12  3.980483e+08
# 3      October           2011   FY 2011-12  4.086132e+08
# 4     November           2011   FY 2011-12  4.657074e+08
# 5     December           2011   FY 2011-12  5.409526e+08
# ..         ...            ...          ...           ...
# 109     August           2020   FY 2020-21  3.589270e+08
# 110  September           2020   FY 2020-21  5.076667e+08
# 111    October           2020   FY 2020-21  5.168324e+08
# 112   November           2020   FY 2020-21  5.411660e+08
# 113   December           2020   FY 2020-21  7.176408e+08
#
#      Income Tax Estimates & Finals  Sales and Use  Business Use  \
# 1                     2.320268e+07   2.666841e+08     927436.95
# 2                     2.748813e+08   2.896617e+08    2769766.79
# 3                     6.944227e+07   3.335668e+08    3798695.47
# ...

# %%
# *************************************Remove in specific rows and columns with Null/NaN values
data.drop(data.index[0])
# Out:
#          Month  Calendar Year Fiscal Year    Withholding  \
# 1       August           2011   FY 2011-12  2.771524e+08
# 2    September           2011   FY 2011-12  3.980483e+08
# 3      October           2011   FY 2011-12  4.086132e+08
# 4     November           2011   FY 2011-12  4.657074e+08
# 5     December           2011   FY 2011-12  5.409526e+08
# ..         ...            ...          ...           ...
# 109     August           2020   FY 2020-21  3.589270e+08
# 110  September           2020   FY 2020-21  5.076667e+08
# 111    October           2020   FY 2020-21  5.168324e+08
# 112   November           2020   FY 2020-21  5.411660e+08
# 113   December           2020   FY 2020-21  7.176408e+08
#
#      Income Tax Estimates & Finals  Sales and Use  Business Use  \
# 1                     2.320268e+07   2.666841e+08     927436.95
# 2                     2.748813e+08   2.896617e+08    2769766.79
# 3                     6.944227e+07   3.335668e+08    3798695.47
# ...

# %%
#keep top 3
data[:3]
# Out:
#        Month  Calendar Year Fiscal Year    Withholding  \
# 0       July           2011   FY 2011-12           NaN
# 1     August           2011   FY 2011-12  2.771524e+08
# 2  September           2011   FY 2011-12  3.980483e+08
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
# 1                   2.320268e+07   2.666841e+08     927436.95      8942131.10
# 2                   2.748813e+08   2.896617e+08    2769766.79     10132507.23
#
#    Electric Generation  Business Entity  ...  Nursing Home User Fee  \
# 0                  NaN        381060.92  ...                    NaN
# 1                  0.0        484492.78  ...             1358440.78
# 2                  0.0        824783.27  ...              664491.99
#
#    Hospitals  Intermediate Care Facility  Ambulatory Surgical Centers  \
# 0        NaN                         NaN                          NaN
# ...

# %%
#drop bottom 3 rows: 111(October),112(November), 113(December)
data[:-3]
# Out:
#          Month  Calendar Year Fiscal Year    Withholding  \
# 0         July           2011   FY 2011-12           NaN
# 1       August           2011   FY 2011-12  2.771524e+08
# 2    September           2011   FY 2011-12  3.980483e+08
# 3      October           2011   FY 2011-12  4.086132e+08
# 4     November           2011   FY 2011-12  4.657074e+08
# ..         ...            ...          ...           ...
# 106        May           2020   FY 2019-20  4.937124e+08
# 107       June           2020   FY 2019-20  1.221656e+09
# 108       July           2020   FY 2020-21           NaN
# 109     August           2020   FY 2020-21  3.589270e+08
# 110  September           2020   FY 2020-21  5.076667e+08
#
#      Income Tax Estimates & Finals  Sales and Use  Business Use  \
# 0                              NaN            NaN           NaN
# 1                     2.320268e+07   2.666841e+08     927436.95
# 2                     2.748813e+08   2.896617e+08    2769766.79
# ...

# %%
# Drop the rows where all elements are missing.
# We couldn't drop all Rows/Columns that had null 
# values given that all entries had some missing values
data.dropna(how='all')
# Out:
#          Month  Calendar Year Fiscal Year    Withholding  \
# 0         July           2011   FY 2011-12           NaN
# 1       August           2011   FY 2011-12  2.771524e+08
# 2    September           2011   FY 2011-12  3.980483e+08
# 3      October           2011   FY 2011-12  4.086132e+08
# 4     November           2011   FY 2011-12  4.657074e+08
# ..         ...            ...          ...           ...
# 109     August           2020   FY 2020-21  3.589270e+08
# 110  September           2020   FY 2020-21  5.076667e+08
# 111    October           2020   FY 2020-21  5.168324e+08
# 112   November           2020   FY 2020-21  5.411660e+08
# 113   December           2020   FY 2020-21  7.176408e+08
#
#      Income Tax Estimates & Finals  Sales and Use  Business Use  \
# 0                              NaN            NaN           NaN
# 1                     2.320268e+07   2.666841e+08     927436.95
# 2                     2.748813e+08   2.896617e+08    2769766.79
# ...

# %%
data.head(1)
# Out:
#   Month  Calendar Year Fiscal Year   Withholding  \
# 0  July           2011   FY 2011-12          NaN
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
#
#    Electric Generation  Business Entity  ...  Nursing Home User Fee  \
# 0                  NaN        381060.92  ...                    NaN
#
#    Hospitals  Intermediate Care Facility  Ambulatory Surgical Centers  \
# 0        NaN                         NaN                          NaN
#
#    Gasoline  Special Fuel  Motor Carrier   Licenses  \
# 0       NaN           NaN            NaN  168768.74
#
#    Beverage Container Deposits  Total Revenue
# 0                          NaN    30584297.58
#
# [1 rows x 51 columns]

# %%
data.drop(['Business Use'], axis = 1)
# Out:
#          Month  Calendar Year Fiscal Year    Withholding  \
# 0         July           2011   FY 2011-12           NaN
# 1       August           2011   FY 2011-12  2.771524e+08
# 2    September           2011   FY 2011-12  3.980483e+08
# 3      October           2011   FY 2011-12  4.086132e+08
# 4     November           2011   FY 2011-12  4.657074e+08
# ..         ...            ...          ...           ...
# 109     August           2020   FY 2020-21  3.589270e+08
# 110  September           2020   FY 2020-21  5.076667e+08
# 111    October           2020   FY 2020-21  5.168324e+08
# 112   November           2020   FY 2020-21  5.411660e+08
# 113   December           2020   FY 2020-21  7.176408e+08
#
#      Income Tax Estimates & Finals  Sales and Use  Room Occupancy  \
# 0                              NaN            NaN             NaN
# 1                     2.320268e+07   2.666841e+08      8942131.10
# 2                     2.748813e+08   2.896617e+08     10132507.23
# ...

# %%
#Select specific columns (This is specific to only columns with numerical data)
data[['Sales and Use', 'Business Entity', 'Motor Carrier']]
# Out:
#      Sales and Use  Business Entity  Motor Carrier
# 0              NaN        381060.92            NaN
# 1     2.666841e+08        484492.78      110712.68
# 2     2.896617e+08        824783.27     1159712.65
# 3     3.335668e+08        461952.67     1747806.95
# 4     3.082123e+08        484246.81      209077.10
# ..             ...              ...            ...
# 109   3.698194e+08              NaN       89440.09
# 110   3.938119e+08              NaN     2593278.45
# 111   3.974856e+08              NaN      213936.70
# 112   4.810005e+08              NaN      128182.29
# 113   4.356304e+08              NaN     2064857.27
#
# [114 rows x 3 columns]

# %%
#Select specific range of columns
data[data.columns[3:6]] # Selecting columns at index 3, 4, 5
# Out:
#       Withholding  Income Tax Estimates & Finals  Sales and Use
# 0             NaN                            NaN            NaN
# 1    2.771524e+08                   2.320268e+07   2.666841e+08
# 2    3.980483e+08                   2.748813e+08   2.896617e+08
# 3    4.086132e+08                   6.944227e+07   3.335668e+08
# 4    4.657074e+08                   8.803835e+07   3.082123e+08
# ..            ...                            ...            ...
# 109  3.589270e+08                   3.323360e+07   3.698194e+08
# 110  5.076667e+08                   3.134048e+08   3.938119e+08
# 111  5.168324e+08                   1.064493e+08   3.974856e+08
# 112  5.411660e+08                   3.622986e+07   4.810005e+08
# 113  7.176408e+08                   8.244990e+07   4.356304e+08
#
# [114 rows x 3 columns]

# %%
data.head(1)
# Out:
#   Month  Calendar Year Fiscal Year   Withholding  \
# 0  July           2011   FY 2011-12          NaN
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
#
#    Electric Generation  Business Entity  ...  Nursing Home User Fee  \
# 0                  NaN        381060.92  ...                    NaN
#
#    Hospitals  Intermediate Care Facility  Ambulatory Surgical Centers  \
# 0        NaN                         NaN                          NaN
#
#    Gasoline  Special Fuel  Motor Carrier   Licenses  \
# 0       NaN           NaN            NaN  168768.74
#
#    Beverage Container Deposits  Total Revenue
# 0                          NaN    30584297.58
#
# [1 rows x 51 columns]

# %%
# Select specific rows and columns using iloc function (df.loc[rows, columns])
data.iloc[0:8, 1:4] # Selecting the first eight rows from with columns at index 1, 2 & 3
# Out:
#    Calendar Year Fiscal Year    Withholding
# 0           2011   FY 2011-12           NaN
# 1           2011   FY 2011-12  2.771524e+08
# 2           2011   FY 2011-12  3.980483e+08
# 3           2011   FY 2011-12  4.086132e+08
# 4           2011   FY 2011-12  4.657074e+08
# 5           2011   FY 2011-12  5.409526e+08
# 6           2012   FY 2011-12  4.931073e+08
# 7           2012   FY 2011-12  4.817713e+08

# %%
data.head(5)
# Out:
#        Month  Calendar Year Fiscal Year    Withholding  \
# 0       July           2011   FY 2011-12           NaN
# 1     August           2011   FY 2011-12  2.771524e+08
# 2  September           2011   FY 2011-12  3.980483e+08
# 3    October           2011   FY 2011-12  4.086132e+08
# 4   November           2011   FY 2011-12  4.657074e+08
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
# 1                   2.320268e+07   2.666841e+08     927436.95      8942131.10
# 2                   2.748813e+08   2.896617e+08    2769766.79     10132507.23
# 3                   6.944227e+07   3.335668e+08    3798695.47      9770714.10
# 4                   8.803835e+07   3.082123e+08    1837456.18     10088593.69
#
#    Electric Generation  Business Entity  ...  Nursing Home User Fee  \
# 0                  NaN        381060.92  ...                    NaN
# ...

# %%
# Replacing Null/Nan values in the dataset with mean, mode median
data.fillna(data.mean()) # Replacing Nan values in the dataset with mean
# Out:
#          Month  Calendar Year Fiscal Year    Withholding  \
# 0         July           2011   FY 2011-12  5.319856e+08
# 1       August           2011   FY 2011-12  2.771524e+08
# 2    September           2011   FY 2011-12  3.980483e+08
# 3      October           2011   FY 2011-12  4.086132e+08
# 4     November           2011   FY 2011-12  4.657074e+08
# ..         ...            ...          ...           ...
# 109     August           2020   FY 2020-21  3.589270e+08
# 110  September           2020   FY 2020-21  5.076667e+08
# 111    October           2020   FY 2020-21  5.168324e+08
# 112   November           2020   FY 2020-21  5.411660e+08
# 113   December           2020   FY 2020-21  7.176408e+08
#
#      Income Tax Estimates & Finals  Sales and Use  Business Use  \
# 0                     2.958321e+08   3.787298e+08  5.320849e+06
# 1                     2.320268e+07   2.666841e+08  9.274369e+05
# 2                     2.748813e+08   2.896617e+08  2.769767e+06
# ...

# %%
# This comes in handy when you have a large data set and there may exist dashes
data = data.replace('-',0) 
data.head(10)
# Out:
#        Month  Calendar Year Fiscal Year    Withholding  \
# 0       July           2011   FY 2011-12           NaN
# 1     August           2011   FY 2011-12  2.771524e+08
# 2  September           2011   FY 2011-12  3.980483e+08
# 3    October           2011   FY 2011-12  4.086132e+08
# 4   November           2011   FY 2011-12  4.657074e+08
# 5   December           2011   FY 2011-12  5.409526e+08
# 6    January           2012   FY 2011-12  4.931073e+08
# 7   February           2012   FY 2011-12  4.817713e+08
# 8      March           2012   FY 2011-12  5.648959e+08
# 9      April           2012   FY 2011-12  3.729647e+08
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
# 1                   2.320268e+07   2.666841e+08     927436.95      8942131.10
# 2                   2.748813e+08   2.896617e+08    2769766.79     10132507.23
# ...

# %% [markdown]
# #### CONCATENATING TWO DIFFERENT DATASETS (DATA AND SENTIMENT_DATA) USING THE  CONCAT() FUNCTION

# %%
data.head(2)
# Out:
#     Month  Calendar Year Fiscal Year    Withholding  \
# 0    July           2011   FY 2011-12           NaN
# 1  August           2011   FY 2011-12  2.771524e+08
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
# 1                    23202684.78   2.666841e+08     927436.95       8942131.1
#
#    Electric Generation  Business Entity  ...  Nursing Home User Fee  \
# 0                  NaN        381060.92  ...                    NaN
# 1                  0.0        484492.78  ...             1358440.78
#
#    Hospitals  Intermediate Care Facility  Ambulatory Surgical Centers  \
# 0        NaN                         NaN                          NaN
# 1        0.0                         0.0                          NaN
#
#       Gasoline  Special Fuel  Motor Carrier   Licenses  \
# 0          NaN           NaN            NaN  168768.74
# ...

# %%
sentiment_data.head(2)
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                        0.0  Virgin America
#
#   airline_sentiment_gold      name negativereason_gold  retweet_count  \
# 0                    NaN   cairdin                 NaN              0
# 1                    NaN  jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# ...

# %%
result = pd.concat([data, sentiment_data], axis=1)

# %%
result.head(1)
# Out:
#   Month  Calendar Year Fiscal Year   Withholding  \
# 0  July         2011.0   FY 2011-12          NaN
#
#    Income Tax Estimates & Finals  Sales and Use  Business Use  Room Occupancy  \
# 0                            NaN            NaN           NaN             NaN
#
#    Electric Generation  Business Entity  ...         airline  \
# 0                  NaN        381060.92  ...  Virgin America
#
#    airline_sentiment_gold     name  negativereason_gold  retweet_count  \
# 0                     NaN  cairdin                  NaN              0
#
#                                   text  tweet_coord  \
# 0  @VirginAmerica What @dhepburn said.          NaN
#
#                tweet_created  tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800             NaN  Eastern Time (US & Canada)
#
# [1 rows x 66 columns]

# %%
# Once we combined both datasets, you notice that the sentiment data sets has more rows 
# setting all additional column values from the financial dataset to Nan
result
# Out:
#            Month  Calendar Year Fiscal Year    Withholding  \
# 0           July         2011.0   FY 2011-12           NaN
# 1         August         2011.0   FY 2011-12  2.771524e+08
# 2      September         2011.0   FY 2011-12  3.980483e+08
# 3        October         2011.0   FY 2011-12  4.086132e+08
# 4       November         2011.0   FY 2011-12  4.657074e+08
# ...          ...            ...          ...           ...
# 14635        NaN            NaN          NaN           NaN
# 14636        NaN            NaN          NaN           NaN
# 14637        NaN            NaN          NaN           NaN
# 14638        NaN            NaN          NaN           NaN
# 14639        NaN            NaN          NaN           NaN
#
#        Income Tax Estimates & Finals  Sales and Use  Business Use  \
# 0                                NaN            NaN           NaN
# 1                       2.320268e+07   2.666841e+08     927436.95
# ...

# %%
data.shape
# Out:
# (114, 51)

# %%
sentiment_data.shape
# Out:
# (14640, 15)

# %%
result.shape
# Out:
# (14640, 66)

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS (EDA)

# %%
# We plotted a Histogram graph showing frequency distributions in a bar set-up
data.hist(figsize=(20,20))
plt.show()

# %%
#Histogram graph to show frequency distributions in a bar set-up
data.plot()
plt.ylabel('XXXXXXXXXXXXX')
# Out:
# Text(0, 0.5, 'XXXXXXXXXXXXX')

# %%
#Bar Graph
data.plot(kind='bar')
plt.ylabel('XXXXXXXXXX')
# Out:
# Text(0, 0.5, 'XXXXXXXXXX')

# %%
#Density plot show the probability density function of the variable in form of  probability distribution.
data.plot(kind='density', subplots=True, layout=(4,4), sharex=False,figsize=(15,20))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-6d276fdfed28> in <module>
#       1 #Density plot show the probability density function of the variable in form of  probability distribution.
# ----> 2 data.plot(kind='density', subplots=True, layout=(4,4), sharex=False,figsize=(15,20))
#       3 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
# ...

# %%
#Seaborn show  visualizing the relationships between the feature
import seaborn as sns
sns.pairplot(data)

# %%
#Line plot
lines = data.plot.line(x='Allocation\rRatio', y='Leasing of Medical\rEquipment')
